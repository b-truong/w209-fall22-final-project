# %% [markdown]
# # Pre-process fight data

# %%
import pandas as pd
df_fight = pd.read_csv('./data/data.csv')

# %% [markdown]
# ### Separate red fighter data

# %%
cols_red_fight = [k for k in df_fight.columns if k[:2] != 'B_' or k == 'B_fighter']
df_red_fight = df_fight.loc[:, cols_red_fight]
df_red_fight.columns = df_red_fight.columns.str.removeprefix('R_')
df_red_fight.columns = df_red_fight.columns.str.replace('B_fighter', 'opponent')
df_red_fight['fighter_color'] = 'Red'
df_red_fight['is_winner'] = (df_red_fight['Winner'] == 'Red').astype(int)

# %% [markdown]
# ### Separate blue fighter data

# %%
cols_blue_fight = [k for k in df_fight.columns if k[:2] != 'R_' or k == 'R_fighter']
df_blue_fight = df_fight.loc[:, cols_blue_fight]
df_blue_fight.columns = df_blue_fight.columns.str.removeprefix('B_')
df_blue_fight.columns = df_blue_fight.columns.str.replace('R_fighter', 'opponent')
df_blue_fight['fighter_color'] = 'Blue'
df_blue_fight['is_winner'] = (df_blue_fight['Winner'] == 'Blue').astype(int)

# %% [markdown]
# ### Combine fighter data and write to file

# %%
df_fight_by_fighters = pd.concat([df_red_fight, df_blue_fight], axis=0).sort_values('date')
df_fight_by_fighters = df_fight_by_fighters.sort_values(by=['fighter', 'date'])
df_fight_by_fighters
# Out:
#                fighter         opponent        Referee        date  \
# 510         Aalon Cruz    Spike Carlyle   Scott Howard  2020-02-29
# 34          Aalon Cruz       Uros Medic     Mark Smith  2021-03-06
# 5779       Aaron Brink  Andrei Arlovski  John McCarthy  2000-11-17
# 3320    Aaron Phillips      Sam Sicilia   Jason Herzog  2014-05-24
# 3168    Aaron Phillips       Matt Hobar      Kevin Nix  2014-08-23
# ...                ...              ...            ...         ...
# 2557  Zubaira Tukhugov   Phillipe Nover     Mark Smith  2015-12-10
# 2361  Zubaira Tukhugov   Renato Moicano  Eduardo Herdy  2016-05-14
# 733   Zubaira Tukhugov    Lerone Murphy      Herb Dean  2019-09-07
# 518   Zubaira Tukhugov    Kevin Aguilar   Marc Goddard  2020-02-22
# 252   Zubaira Tukhugov    Hakeem Dawodu   Kevin Sataki  2020-09-26
#
#                                         location Winner  title_bout  \
# 510                       Norfolk, Virginia, USA   Blue       False
# 34                        Las Vegas, Nevada, USA    Red       False
# 5779              Atlantic City, New Jersey, USA    Red       False
# 3320                      Las Vegas, Nevada, USA    Red       False
# 3168                        Tulsa, Oklahoma, USA   Blue       False
# ...                                          ...    ...         ...
# 2557                      Las Vegas, Nevada, USA    Red       False
# 2361                    Curitiba, Parana, Brazil    Red       False
# 733   Abu Dhabi, Abu Dhabi, United Arab Emirates   Draw       False
# 518                        Auckland, New Zealand   Blue       False
# 252   Abu Dhabi, Abu Dhabi, United Arab Emirates    Red       False
#
#        weight_class  avg_KD  avg_opp_KD  ...  win_by_KO/TKO  \
# 510   Featherweight     NaN         NaN  ...              0
# 34      Lightweight    0.00         0.0  ...              0
# 5779    Heavyweight     NaN         NaN  ...              0
# 3320  Featherweight     NaN         NaN  ...              0
# 3168   Bantamweight    0.00         0.0  ...              0
# ...             ...     ...         ...  ...            ...
# 2557  Featherweight    0.00         0.0  ...              1
# 2361  Featherweight    0.00         0.0  ...              1
# 733   Featherweight    0.00         0.0  ...              1
# 518   Featherweight    0.50         0.0  ...              1
# 252   Featherweight    1.25         0.0  ...              2
#
#       win_by_Submission  win_by_TKO_Doctor_Stoppage    Stance  Height_cms  \
# 510                   0                           0    Switch      182.88
# 34                    0                           0    Switch      182.88
# 5779                  0                           0  Orthodox      190.50
# 3320                  0                           0  Southpaw      175.26
# 3168                  0                           0  Southpaw      175.26
# ...                 ...                         ...       ...         ...
# 2557                  0                           0  Orthodox      172.72
# 2361                  0                           0  Orthodox      172.72
# 733                   0                           0  Orthodox      172.72
# 518                   0                           0  Orthodox      172.72
# 252                   0                           0  Orthodox      172.72
#
#       Reach_cms  Weight_lbs   age  fighter_color  is_winner
# 510      198.12       145.0  30.0            Red          0
# 34       198.12       145.0  31.0           Blue          0
# 5779        NaN       205.0  26.0           Blue          0
# 3320     180.34       135.0  24.0           Blue          0
# 3168     180.34       135.0  25.0            Red          0
# ...         ...         ...   ...            ...        ...
# 2557     172.72       145.0  24.0            Red          1
# 2361     172.72       145.0  25.0           Blue          0
# 733      172.72       145.0  28.0            Red          0
# 518      172.72       145.0  29.0           Blue          1
# 252      172.72       145.0  29.0           Blue          0
#
# [12024 rows x 78 columns]

# %%
df_fight_by_fighters.to_csv('../src/data/fight_by_fighters.csv')

# %% [markdown]
# ### Create index of fighters based on those in data set

# %%
df_fighters_list = df_fight_by_fighters.copy().drop_duplicates(subset='fighter', keep="last")
df_fighters_list
# Out:
#                  fighter            opponent         Referee        date  \
# 34            Aalon Cruz          Uros Medic      Mark Smith  2021-03-06
# 5779         Aaron Brink     Andrei Arlovski   John McCarthy  2000-11-17
# 375       Aaron Phillips          Jack Shore       Herb Dean  2020-07-15
# 3686         Aaron Riley        Justin Salas    Randy Corley  2013-07-27
# 4148          Aaron Rosa       James Te Huna    Leon Roberts  2012-03-02
# ...                  ...                 ...             ...         ...
# 89    Zhalgas Zhumagulov         Amir Albazi    Jason Herzog  2021-01-23
# 2818        Zhang Lipeng       Kajan Johnson  Greg Kleynjans  2015-05-16
# 3936       Zhang Tiequan            Jon Tuck    Marc Goddard  2012-11-10
# 493          Zhang Weili  Joanna Jedrzejczyk  Keith Peterson  2020-03-07
# 252     Zubaira Tukhugov       Hakeem Dawodu    Kevin Sataki  2020-09-26
#
#                                         location Winner  title_bout  \
# 34                        Las Vegas, Nevada, USA    Red       False
# 5779              Atlantic City, New Jersey, USA    Red       False
# 375   Abu Dhabi, Abu Dhabi, United Arab Emirates    Red       False
# 3686                    Seattle, Washington, USA   Blue       False
# 4148          Sydney, New South Wales, Australia    Red       False
# ...                                          ...    ...         ...
# 89    Abu Dhabi, Abu Dhabi, United Arab Emirates    Red       False
# 2818                         Manila, Philippines   Blue       False
# 3936                                Macau, China   Blue       False
# 493                       Las Vegas, Nevada, USA    Red        True
# 252   Abu Dhabi, Abu Dhabi, United Arab Emirates    Red       False
#
#           weight_class  avg_KD  avg_opp_KD  ...  win_by_KO/TKO  \
# 34         Lightweight    0.00    0.000000  ...              0
# 5779       Heavyweight     NaN         NaN  ...              0
# 375       Bantamweight    0.00    0.000000  ...              0
# 3686       Lightweight    0.00    0.039062  ...              0
# 4148  LightHeavyweight    0.00    0.000000  ...              0
# ...                ...     ...         ...  ...            ...
# 89           Flyweight    0.00    0.000000  ...              0
# 2818       Lightweight    0.00    0.000000  ...              0
# 3936       Lightweight    0.00    1.000000  ...              0
# 493   WomenStrawweight    0.50    0.000000  ...              1
# 252      Featherweight    1.25    0.000000  ...              2
#
#       win_by_Submission  win_by_TKO_Doctor_Stoppage    Stance  Height_cms  \
# 34                    0                           0    Switch      182.88
# 5779                  0                           0  Orthodox      190.50
# 375                   0                           0  Southpaw      175.26
# 3686                  0                           0  Southpaw      172.72
# 4148                  0                           0  Orthodox      193.04
# ...                 ...                         ...       ...         ...
# 89                    0                           0    Switch      162.56
# 2818                  0                           0  Southpaw      180.34
# 3936                  1                           0  Orthodox      172.72
# 493                   1                           0    Switch      162.56
# 252                   0                           0  Orthodox      172.72
#
#       Reach_cms  Weight_lbs   age  fighter_color  is_winner
# 34       198.12       145.0  31.0           Blue          0
# 5779        NaN       205.0  26.0           Blue          0
# 375      180.34       135.0  30.0           Blue          0
# 3686     175.26       155.0  32.0            Red          0
# 4148     195.58       205.0  28.0           Blue          0
# ...         ...         ...   ...            ...        ...
# 89       167.64       125.0  32.0           Blue          0
# 2818     180.34       155.0  25.0            Red          0
# 3936     175.26       155.0  34.0            Red          0
# 493      160.02       115.0  30.0            Red          1
# 252      172.72       145.0  29.0           Blue          0
#
# [2139 rows x 78 columns]

# %%
df_fighters_list.to_csv('../src/data/fighters_list.csv')
